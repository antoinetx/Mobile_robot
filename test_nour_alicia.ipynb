# %%
import tdmclient.notebook
await tdmclient.notebook.start()

# %%
import cv2
import math

import numpy as np
import matplotlib.pyplot as plt
from numpy.core.fromnumeric import size
from matplotlib import colors
from asgiref.sync import sync_to_async #in order to load variables to communicate between sync and async

import optimal_path as op

from robot import Robot
from Map import Map
from Local_navigation import* 
from Mouvement import*
#from vision import*
from optimal_path import* 


map_lenght = 1
nb_of_square_by_side = 50
current = 1

global move 
move = False #bool which indicate how our robot is moving (1: avoid an object VS 0: following the optimal path)
kalman_bool = False
old_distance = 0
old_angle = 0
ERR_POS = 3
#pourcentage_reduc = 1

# %%
@tdmclient.notebook.sync_var
def motors(l_speed=500, r_speed=500, verbose=False):
    """
    Sets the motor speeds of the Thymio 
    param l_speed: left motor speed
    param r_speed: right motor speed
    param verbose: whether to print status messages or not
    """
    global motor_left_target, motor_right_target
    # Printing the speeds if requested
    if verbose:
        print("\t\t Setting speed : ", l_speed, r_speed)
    motor_left_target = l_speed
    motor_right_target = r_speed

# %%
@tdmclient.notebook.sync_var
def proxi():
    """
    Returns the proximity values of the Thymio 
    """
    global prox_horizontal
    return prox_horizontal

# %%
old_distance = 0
old_angle = 0
soon_arrived = False
thresh_indentation = 15
move = False


while True :
    
    proximity = proxi()
    print ('proximity', proximity)

    #move = check_cars(prox_horizonta=proximity)
    print('move check cars', move)

        #LOCAL NAVIGATION
    if move :
        #Thymio is avoiding obstacles
        print("OBSTACLLLEEEE")
        speed_l, speed_r, move = avoid_obstacle(prox_horizonta=proximity) 
    else:
        #Thymio is following the optimal path
        print("Avancee")
        speed_l, speed_r = 70, 70 
        #Thymio is checking if there's an obstacle in front of it
        move = check_cars(prox_horizonta=proximity)
        print (speed_l, speed_r)


    
    motors(speed_l, speed_r) 
    keyVal = cv2.waitKey(1) & 0xFF
    if keyVal == ord('q'):
        motors(0,0)
        break
     
    sleep(0.1)
# Out:
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1372, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1372, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1372, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1759, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1856, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1956, 1317, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1956, 1317, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1956, 1317, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1956, 1317, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1821, 2188, 1682, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1821, 2188, 1682, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1821, 2188, 1682, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [2490, 2354, 1957, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [2759, 2441, 2087, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [2759, 2441, 2087, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [3046, 2559, 2234, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [2759, 2441, 2087, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [2759, 2441, 2087, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [2759, 2441, 2087, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [2582, 1572, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [2582, 1572, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [2582, 1572, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 1103, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [2046, 1551, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [2046, 1551, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [2100, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1151, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1344, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1479, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1479, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1659, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1659, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1659, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1962, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 1347, 2136, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 1347, 2136, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 1425, 2277, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 0, 2207, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2207, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2207, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1270, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1270, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1270, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1693, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1693, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 1693, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 49
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 48
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 47
# proximity [0, 0, 0, 0, 2044, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 46
# proximity [0, 0, 0, 0, 2587, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 45
# proximity [0, 0, 0, 0, 2587, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 44
# proximity [0, 0, 0, 0, 2587, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 43
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 42
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 41
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 40
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 39
# proximity [0, 0, 0, 0, 2579, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 38
# proximity [0, 0, 0, 0, 2579, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 37
# proximity [0, 0, 0, 0, 2586, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 36
# proximity [0, 0, 0, 0, 2586, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 35
# proximity [0, 0, 0, 0, 2586, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 34
# proximity [0, 0, 0, 0, 2586, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 33
# proximity [0, 0, 0, 0, 2583, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 32
# proximity [0, 0, 0, 0, 2583, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 31
# proximity [0, 0, 0, 0, 2583, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 30
# proximity [0, 0, 0, 0, 2583, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 29
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 28
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 27
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 26
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 25
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 24
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 23
# proximity [0, 0, 0, 0, 2592, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 22
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 21
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 20
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 19
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 18
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 17
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 16
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 15
# proximity [0, 0, 0, 0, 2582, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 14
# proximity [0, 0, 0, 0, 2582, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 13
# proximity [0, 0, 0, 0, 2582, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 12
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 11
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 10
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 9
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 8
# proximity [0, 0, 0, 0, 2585, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 7
# proximity [0, 0, 0, 0, 2585, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 6
# proximity [0, 0, 0, 0, 2585, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 5
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 4
# proximity [0, 0, 0, 0, 2584, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 3
# proximity [0, 0, 0, 0, 2587, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 2
# proximity [0, 0, 0, 0, 2587, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 1
# proximity [0, 0, 0, 0, 2582, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 0
# proximity [0, 0, 0, 0, 2582, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2582, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2581, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1991, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1991, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1991, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1991, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1991, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1882, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1882, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1882, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 1882, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2065, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2065, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2065, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2065, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2363, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2363, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2363, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2274, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2274, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2274, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2250, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2250, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2318, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2318, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2318, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2384, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2384, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2384, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2208, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2208, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2208, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2208, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 2208, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1355, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1355, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1269, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1406, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1406, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1340, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 3238, 4119, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 3238, 4119, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2139, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2139, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2546, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2546, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2546, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3772, 1452, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [3772, 1452, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [3772, 1452, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4216, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4216, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4216, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4216, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4216, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4216, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 1512, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 1512, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 1834, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 1834, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 0, 3061, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2325, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2325, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2371, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2371, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2371, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2465, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2465, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2465, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2695, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2695, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2821, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2821, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3212, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3212, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3212, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3696, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3696, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3812, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3812, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 4055, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 4055, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 4117, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 4117, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3878, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3878, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 3878, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2796, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2796, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2796, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 2796, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 49
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 48
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 47
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 46
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 45
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 44
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 43
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 42
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 41
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 40
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 39
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 38
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 37
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 36
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 35
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 34
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 33
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 32
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 31
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 30
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 29
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 28
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 27
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 26
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 25
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 24
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 23
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 22
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 21
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 20
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 19
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 18
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 17
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 16
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 15
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 14
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 13
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 12
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 11
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 10
# proximity [0, 0, 0, 1820, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 1820, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 0, 0, 2001, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 9
# proximity [0, 0, 0, 0, 0, 2001, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 8
# proximity [0, 0, 0, 0, 0, 2001, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 7
# proximity [0, 0, 0, 0, 0, 2001, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 6
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 5
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 4
# ...
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_42056/3631288799.py in <module>
#      35         break
#      36
# ---> 37     sleep(0.1)
#      38
#      39
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\repl.py in sleep(t)
#      54
#      55             # send and flush all variables which might have been changed
# ---> 56             self.send_variables(self.var_set)
#      57
#      58             # wait
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\repl.py in send_variables(self, names_py, node_flush)
#     461                 self.send_variable(name_py, self.local_var[name_py])
#     462             if node_flush:
# --> 463                 self.flush_variables()
#     464
#     465     def find_global_var(self, nodes, globals=None):
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\repl.py in flush_variables(self)
#     454
#     455     def flush_variables(self):
# --> 456         self.node.flush()
#     457
#     458     def send_variables(self, names_py, node_flush=True):
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\clientasynccachenode.py in flush(self)
#     143         self.send_set_variables(self.var_to_send)
#     144         # process waiting messages, possibly changing self.var
# --> 145         self.thymio.process_waiting_messages()
#     146         # overwrite variables just sent in case they've been replaced by older values
#     147         self.var = {**self.var, **self.var_to_send}
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\client.py in process_waiting_messages(self)
#     128                 if self.debug >= 3:
#     129                     print("recv", msg)
# --> 130                 self.process_message(msg)
#     131                 at_least_one = True
#     132         return at_least_one
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\thymio.py in process_message(self, msg)
#     583
#     584         fb = FlatBuffer()
# --> 585         fb.parse(msg, ThymioFB.SCHEMA)
#     586         if self.debug >= 2:
#     587             fb.dump()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\fb.py in parse(self, encoded_fb, schema)
#     164         if schema[0] not in "TU":
#     165             raise Exception("unexpected schema")
# --> 166         self.root = FlatBuffer.parse_value(encoded_fb, 0, schema)
#     167
#     168     @staticmethod
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     290             if len(vtable) > 1:
#     291                 pos_field = table_pos + vtable[1]
# --> 292                 union_value = FlatBuffer.parse_value(encoded_fb,
#     293                                                      pos_field,
#     294                                                      schema[ix_schema:])
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     254                     # decode field
#     255                     pos_field = table_pos + vtable[len(fields)]
# --> 256                     field_value = FlatBuffer.parse_value(encoded_fb,
#     257                                                          pos_field,
#     258                                                          schema[ix_schema:])
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     228                 for i in range(vec_len):
#     229                     # decode element
# --> 230                     els.append(FlatBuffer.parse_value(encoded_fb,
#     231                                                       vec_pos + 4 + i * el_size,
#     232                                                       schema[1:]))
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     254                     # decode field
#     255                     pos_field = table_pos + vtable[len(fields)]
# --> 256                     field_value = FlatBuffer.parse_value(encoded_fb,
#     257                                                          pos_field,
#     258                                                          schema[ix_schema:])
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     215             str_pos = pos + FlatBuffer.decode_i32(encoded_fb, pos)
#     216             str_len = FlatBuffer.decode_u32(encoded_fb, str_pos)
# --> 217             return str(encoded_fb[str_pos + 4 : str_pos + 4 + str_len], "utf-8")
#     218         elif schema[0] == "*":
#     219             # decode vector
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 1: invalid continuation byte
