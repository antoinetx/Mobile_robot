# %%
import tdmclient.notebook
await tdmclient.notebook.start()

# %%
import cv2
import math

import numpy as np
import matplotlib.pyplot as plt
from numpy.core.fromnumeric import size
from matplotlib import colors
from asgiref.sync import sync_to_async #in order to load variables to communicate between sync and async

import optimal_path as op

from robot import Robot
from Map import Map
from Local_navigation import* 
from Mouvement import*
from vision import*
from optimal_path import* 


map_lenght = 1
nb_of_square_by_side = 50
current = 1

global move 
move = False #bool which indicate how our robot is moving (1: avoid an object VS 0: following the optimal path)
kalman_bool = False
old_distance = 0
old_angle = 0
ERR_POS = 3
#pourcentage_reduc = 1

# %%
@tdmclient.notebook.sync_var
def motors(l_speed=500, r_speed=500, verbose=False):
    """
    Sets the motor speeds of the Thymio 
    param l_speed: left motor speed
    param r_speed: right motor speed
    param verbose: whether to print status messages or not
    """
    global motor_left_target, motor_right_target
    # Printing the speeds if requested
    if verbose:
        print("\t\t Setting speed : ", l_speed, r_speed)
    motor_left_target = l_speed
    motor_right_target = r_speed

# %%
@tdmclient.notebook.sync_var
def proxi():
    """
    Returns the proximity values of the Thymio 
    """
    global prox_horizontal
    return prox_horizontal

# %%
old_distance = 0
old_angle = 0
soon_arrived = False
thresh_indentation = 15
move = False


while True :
    
    proximity = proxi()
    print ('proximity', proximity)

    #move = check_cars(prox_horizonta=proximity)
    print('move check cars', move)

        #LOCAL NAVIGATION
    if move :
        #Thymio is avoiding obstacles
        print("OBSTACLLLEEEE")
        speed_l, speed_r, move = avoid_obstacle(prox_horizonta=proximity) 
    else:
        #Thymio is following the optimal path
        print("Avancee")
        speed_l, speed_r = 70, 70 
        #Thymio is checking if there's an obstacle in front of it
        move = check_cars(prox_horizonta=proximity)
        print (speed_l, speed_r)


    
    motors(speed_l, speed_r) 
    keyVal = cv2.waitKey(1) & 0xFF
    if keyVal == ord('q'):
        motors(0,0)
        break
     
    sleep(0.1)
# Out:
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [947, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1250, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1250, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1321, 0, 0, 886, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1321, 0, 0, 886, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1321, 0, 0, 886, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1533, 0, 0, 886, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1711, 991, 2239, 2819, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1711, 991, 2239, 2819, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1834, 1058, 2367, 3062, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1834, 1058, 2367, 3062, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1607, 1199, 2820, 3131, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1607, 1199, 2820, 3131, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1617, 1377, 3443, 2616, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1617, 1377, 3443, 2616, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1617, 1377, 3443, 2616, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1102, 3440, 3977, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1102, 3440, 3977, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [1679, 4287, 3544, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [3134, 4507, 2550, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [3134, 4507, 2550, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [4765, 4602, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4765, 4602, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4765, 4602, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4062, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4062, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4786, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4786, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4783, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4783, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4762, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4762, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4426, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4426, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3930, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3670, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3670, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3670, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3670, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4868, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4868, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4868, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4868, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3951, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3951, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3889, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3889, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3545, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3545, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3514, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3514, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3514, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [3514, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1837, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1837, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1837, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 49
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 48
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 47
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 46
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 45
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 44
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 43
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 42
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 41
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 40
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 39
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 38
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 37
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 36
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 35
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 34
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 33
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 32
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 31
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 30
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 29
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 28
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 27
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 26
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 25
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 24
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 23
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 22
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 21
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 20
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 19
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 18
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 17
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 16
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 15
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 14
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 13
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 12
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 11
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 10
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 9
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 8
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 7
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 6
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 5
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 4
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 2
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 1
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 0
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40444/3631288799.py in <module>
#      35         break
#      36
# ---> 37     sleep(0.1)
#      38
#      39
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\repl.py in sleep(t)
#      57
#      58             # wait
# ---> 59             ClientAsync.aw(self.client.sleep(t))
#      60
#      61             # fetch all variables which might be used
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\clientasync.py in aw(co)
#     166             r = await co
#     167
# --> 168         ClientAsync.run_async_program(prog)
#     169         return r
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\clientasync.py in run_async_program(prog)
#     151         try:
#     152             while True:
# --> 153                 co.send(None)
#     154         except StopIteration:
#     155             pass
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\clientasync.py in prog()
#     164         async def prog():
#     165             nonlocal r
# --> 166             r = await co
#     167
#     168         ClientAsync.run_async_program(prog)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tdmclient\clientasync.py in sleep(self, duration, wake)
#      41         while duration < 0 or monotonic() < t0 + duration:
#      42             self.process_waiting_messages()
# ---> 43             sleep(self.DEFAULT_SLEEP
#      44                   if duration < 0
#      45                   else max(min(self.DEFAULT_SLEEP, t0 + duration - monotonic()),
#
# KeyboardInterrupt:
