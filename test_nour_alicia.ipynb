# %%
import tdmclient.notebook
await tdmclient.notebook.start()

# %%
import cv2
import math

import numpy as np
import matplotlib.pyplot as plt
from numpy.core.fromnumeric import size
from matplotlib import colors
from asgiref.sync import sync_to_async #in order to load variables to communicate between sync and async

import optimal_path as op

from robot import Robot
from Map import Map
from Local_navigation import* 
from Mouvement import*
from vision import*
from optimal_path import* 


map_lenght = 1
nb_of_square_by_side = 50
current = 1

global move 
move = False #bool which indicate how our robot is moving (1: avoid an object VS 0: following the optimal path)
kalman_bool = False
old_distance = 0
old_angle = 0
ERR_POS = 3
#pourcentage_reduc = 1

# %%
@tdmclient.notebook.sync_var
def motors(l_speed=500, r_speed=500, verbose=False):
    """
    Sets the motor speeds of the Thymio 
    param l_speed: left motor speed
    param r_speed: right motor speed
    param verbose: whether to print status messages or not
    """
    global motor_left_target, motor_right_target
    # Printing the speeds if requested
    if verbose:
        print("\t\t Setting speed : ", l_speed, r_speed)
    motor_left_target = l_speed
    motor_right_target = r_speed

# %%
@tdmclient.notebook.sync_var
def proxi():
    """
    Returns the proximity values of the Thymio 
    """
    global prox_horizontal
    return prox_horizontal

# %%
old_distance = 0
old_angle = 0
soon_arrived = False
thresh_indentation = 15
move = False


while True :
    
    proximity = proxi()
    print ('proximity', proximity)

    #move = check_cars(prox_horizonta=proximity)
    print('move check cars', move)

        #LOCAL NAVIGATION
    if move :
        #Thymio is avoiding obstacles
        print("OBSTACLLLEEEE")
        speed_l, speed_r, move = avoid_obstacle(prox_horizonta=proximity) 
    else:
        #Thymio is following the optimal path
        print("Avancee")
        speed_l, speed_r = 70, 70 
        #Thymio is checking if there's an obstacle in front of it
        move = check_cars(prox_horizonta=proximity)
        print (speed_l, speed_r)


    
    motors(speed_l, speed_r) 
    keyVal = cv2.waitKey(1) & 0xFF
    if keyVal == ord('q'):
        motors(0,0)
        break
     
    sleep(0.1)
# Out:
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1396, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1482, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1482, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1482, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1861, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1316, 2018, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1316, 2018, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1570, 2173, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1570, 2173, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1910, 2425, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1910, 2425, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 2144, 2609, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 2144, 2609, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 2144, 2609, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 2517, 2933, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 2517, 2933, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 2952, 3305, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 3311, 3576, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [0, 3691, 3865, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [0, 3691, 3865, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [0, 3691, 3865, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [4810, 4097, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4810, 4097, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4799, 3318, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4799, 3318, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4771, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4771, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 49
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 48
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 47
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 46
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 45
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 44
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 43
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 42
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 41
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 40
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 39
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 38
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 37
# proximity [0, 0, 0, 0, 0, 0, 2228]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 36
# proximity [0, 0, 0, 0, 0, 0, 2228]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 35
# proximity [0, 0, 0, 0, 0, 0, 2228]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 34
# proximity [0, 0, 0, 0, 0, 0, 2470]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 33
# proximity [0, 0, 0, 0, 0, 1582, 2506]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 32
# proximity [0, 0, 0, 0, 0, 1582, 2506]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 31
# proximity [0, 0, 0, 0, 0, 1582, 2506]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 30
# proximity [0, 0, 0, 0, 0, 1582, 2506]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 29
# proximity [0, 0, 0, 0, 0, 1850, 2553]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 28
# proximity [0, 0, 0, 0, 0, 1850, 2553]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 27
# proximity [0, 0, 0, 0, 0, 2783, 2915]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 26
# proximity [0, 0, 0, 0, 0, 2783, 2915]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 25
# proximity [0, 0, 0, 0, 0, 2783, 2915]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 24
# proximity [0, 0, 0, 0, 0, 3091, 2795]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 23
# proximity [0, 0, 0, 0, 0, 3091, 2795]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 22
# proximity [0, 0, 0, 0, 0, 3053, 2601]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 21
# proximity [0, 0, 0, 0, 0, 3053, 2601]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 20
# proximity [0, 0, 0, 0, 0, 3053, 2601]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 19
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 18
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 17
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 16
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 15
# proximity [0, 0, 0, 0, 0, 3159, 2854]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 14
# proximity [0, 0, 0, 0, 0, 3159, 2854]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 13
# proximity [0, 0, 0, 0, 0, 3159, 2854]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 12
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 11
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 10
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 9
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 8
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 7
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 6
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 5
# proximity [0, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 4
# proximity [2479, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 3
# proximity [2479, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 2
# proximity [2479, 0, 0, 0, 0, 3162, 2647]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 1
# proximity [1617, 0, 0, 0, 0, 3101, 2744]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 0
# proximity [1617, 0, 0, 0, 0, 3101, 2744]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1617, 0, 0, 0, 0, 3101, 2744]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 3101, 2744]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 3101, 2744]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 2312, 1835]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 2312, 1835]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1332, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1332, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1332, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1639, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1639, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1639, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1974, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1974, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 1974, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1716, 2249, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1716, 2249, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1716, 2249, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [1716, 2249, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [2398, 2558, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [2839, 2749, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [2839, 2749, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [3210, 2903, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [3210, 2903, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [3730, 2890, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# proximity [4396, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4396, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4396, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [4396, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1520, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1816, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1918, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [1918, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2004, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2040, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2040, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2040, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2179, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2179, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2179, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2325, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2325, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2325, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2456, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2456, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2523, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2587, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2644, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2644, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2702, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2746, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2746, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2746, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2797, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2797, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2797, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2812, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2812, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2513, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2513, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2513, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2513, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [2513, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 49
# proximity [0, 0, 0, 0, 0, 0, 2476]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 48
# proximity [0, 0, 0, 0, 0, 0, 2476]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 47
# proximity [0, 0, 0, 0, 0, 0, 2476]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 46
# proximity [2253, 0, 0, 0, 0, 0, 2476]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 45
# proximity [2253, 0, 0, 0, 0, 0, 2476]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 44
# proximity [2253, 0, 0, 0, 0, 0, 2476]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 43
# proximity [0, 0, 0, 0, 0, 1841, 2365]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 42
# proximity [0, 0, 0, 0, 0, 1841, 2365]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 41
# proximity [0, 0, 0, 0, 0, 2039, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 40
# proximity [0, 0, 0, 0, 0, 2039, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 39
# proximity [0, 0, 0, 0, 0, 2039, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 38
# proximity [0, 0, 0, 0, 0, 2276, 2276]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 37
# proximity [0, 0, 0, 0, 0, 2276, 2276]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 36
# proximity [0, 0, 0, 0, 0, 2276, 2276]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 35
# proximity [0, 0, 0, 0, 0, 2276, 2276]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 34
# proximity [0, 0, 0, 0, 0, 2323, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 33
# proximity [0, 0, 0, 0, 0, 2323, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 32
# proximity [0, 0, 0, 0, 0, 2323, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 31
# proximity [0, 0, 0, 0, 0, 2323, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 30
# proximity [0, 0, 0, 0, 0, 2323, 2288]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 29
# proximity [0, 0, 0, 0, 0, 0, 2080]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 28
# proximity [0, 0, 0, 0, 0, 0, 2080]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 27
# proximity [0, 0, 0, 0, 0, 0, 1532]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 26
# proximity [0, 0, 0, 0, 0, 0, 1532]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 25
# proximity [0, 0, 0, 0, 0, 0, 1532]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 24
# proximity [0, 0, 0, 0, 0, 0, 1532]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 23
# proximity [0, 0, 0, 0, 0, 0, 1532]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 22
# proximity [0, 0, 0, 0, 0, 0, 1386]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 21
# proximity [0, 0, 0, 0, 0, 0, 1386]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 20
# proximity [0, 0, 0, 0, 0, 0, 1413]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 19
# proximity [0, 0, 0, 0, 0, 0, 1413]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 18
# proximity [0, 0, 0, 0, 0, 0, 1413]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 17
# proximity [0, 0, 0, 0, 0, 0, 1266]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 16
# proximity [0, 0, 0, 0, 0, 0, 1266]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 15
# proximity [0, 0, 0, 0, 0, 0, 1266]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 14
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 13
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 12
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 11
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 10
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 9
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 8
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 7
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 6
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 5
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 4
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 2
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 1
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# compteur 0
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 1168, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 1519, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 1519, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 1771, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 1898, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 1898, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1170, 2245, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1170, 2245, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1360, 2493, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1600, 2766, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 1600, 2766, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [0, 0, 1600, 2766, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [0, 0, 1956, 3246, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# proximity [0, 0, 0, 3671, 1876, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 3875, 3758, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 3875, 3758, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 2339, 4295, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 2339, 4295, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 0, 4280, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 2339, 4295, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# dans la boucle 2
# dans la boucle 3
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars True
# OBSTACLLLEEEE
# dans la boucle 1
# ...
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
# proximity [0, 0, 0, 0, 0, 0, 0]
# move check cars False
# Avancee
# 70 70
