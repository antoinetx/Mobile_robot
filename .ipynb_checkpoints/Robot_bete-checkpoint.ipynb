# %% [markdown]
# Implementation of "stupid" Thymios which will challenge the "clever" one
#
# Author: Alicia Mauroux, Robotic MA1, Fall 2021
#
# This robot have to follow a lign
# It stops when it sees an object in front of it
# When it losts its lign, the idiot Thymio is in "lost" mode

# %%
# !pip3 install asgiref
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting asgiref
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Installing collected packages: asgiref
# Successfully installed asgiref-3.4.1

# %%
# Import tdmclient Notebook environment:
import tdmclient.notebook
await tdmclient.notebook.start()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/w4/rlzv9syd0416nt9tchvspk1m0000gn/T/ipykernel_1018/2535939621.py in <module>
#       1 # Import tdmclient Notebook environment:
#       2 import tdmclient.notebook
# ----> 3 await tdmclient.notebook.start()
#
# ~/Library/Python/3.8/lib/python/site-packages/tdmclient/notebook/__init__.py in start(tdm_addr, tdm_port, **kwargs)
#      91     client = ClientAsync(tdm_addr=tdm_addr, tdm_port=tdm_port)
#      92     node = await client.wait_for_node(**kwargs)
# ---> 93     await node.lock()
#      94
#      95     global _interactive_console
#
# ~/Library/Python/3.8/lib/python/site-packages/tdmclient/clientasyncnode.py in lock(self)
#      58         result = yield from self.lock_node()
#      59         if result is not None:
# ---> 60             raise Exception("Node lock error")
#      61         return self
#      62
#
# Exception: Node lock error

# %%
from asgiref.sync import sync_to_async

# %%
test_functions = True

# %%
#constants
LED = 32

lost = False
w_le_old = 0 
w_ri_old = 0
sum_error_l = 0
sum_error_r = 0
l_s_old = 0 
r_s_old = 0

# %% [markdown]
# Function in order to control the leds. It will tell us if the robot is doing its job or if it's lost.

# %%
@tdmclient.notebook.sync_var
def light_em_up(left=0,right=0):
    global leds_top, leds_buttons, leds_circle, lost 
    if lost:
        #red
        leds_top = [LED, 0, 0]
    else:
        #yellow
        leds_top = [LED,LED,0]
        leds_circle = [0,0,0,0,0,0,LED,0]
    if left:
        leds_circle = [0,0,0,0,0,0,LED,0]
    elif right: 
        leds_circle = [0,0,LED,0,0,0,0,0]
    else:
        leds_circle = [0,0,0,0,0,0,0,0]

# %%
if test_functions:
    light_em_up()

# %%
@tdmclient.notebook.sync_var
def motors(l_speed=500, r_speed=500, verbose=False):
    """
    Sets the motor speeds of the Thymio 
    param l_speed: left motor speed
    param r_speed: right motor speed
    param verbose: whether to print status messages or not
    """
    global motor_left_target, motor_right_target
    # Printing the speeds if requested
    if verbose:
        print("\t\t Setting speed : ", l_speed, r_speed)
    motor_left_target = l_speed
    motor_right_target = r_speed

# %%
if test_functions:
    motors(100, 100) #test with lower speed value
    sleep(2)
    motors(0, 0)

# %% [markdown]
# Sensors functions

# %%
@tdmclient.notebook.sync_var
def test_ground_white(white_threshold=600, verbose=False):
    """
    Tests whether the two ground sensors have seen white
    param white_threshold: threshold starting which it is considered that the sensor saw white
    param verbose: whether to print status messages or not
    """
    global turn_left, prox_ground_reflected, leds_circle, leds_buttons, lost, w_le_old, w_ri_old, w_le, w_ri
    
    
   # print(prox_ground_reflected)
    
    
    w_le = prox_ground_reflected[0] 
    w_ri = prox_ground_reflected[1] 
    #"smoothing" data
    w_le = (w_le + w_le_old)//2
    w_ri = (w_ri + w_ri_old)//2
    w_le_old = w_le
    w_ri_old = w_ri
    
    #white on the left --> turn right then to keep the track
    if (w_le > white_threshold)&(w_ri < white_threshold):
        turn_left = False
        lost = False
        light_em_up(0,1)
        return True
    #white on the right --> turn left then to keep the track
    elif (w_le < white_threshold)&(w_ri > white_threshold):
        lost = False
        turn_left = True
        light_em_up(1,0)
        return True
    #white on both direction --> you lost the track! turn back
    elif (w_le > white_threshold)&(w_ri > white_threshold):
        lost = True
        turn_left = False
        light_em_up()
        return True
    else:
        lost = False
        turn_left = False
        light_em_up()
        return False

# %%
if test_functions:
    test_ground_white()
    print(turn_left)
# Out:
# [85, 368]
# 642
# True

# %% [markdown]
# PI

# %%
@tdmclient.notebook.sync_var
def PI(goal=100):
    global sum_error_l, sum_error_r, w_le, w_ri, turn_left, lost, l_s_old, r_s_old
    error_tres = 0.1
    KP = 10
    KI = 0.5
    MAX_SPEED = 100
    MAX_ERROR = 800
    SPEED = 25
    
#    print("w_le = ", w_le)
 #   print("w_ri = ", w_ri)
    
    error_l = MAX_ERROR-(w_le - goal)//100
    error_r = MAX_ERROR-(w_ri - goal)//100
    if (abs(error_l) < error_tres):
        error_l = 0
    if (abs(error_r) < error_tres):
        error_r = 0
    
    sum_error_l = sum_error_l + error_l
    sum_error_r = sum_error_r + error_r
    
    if (sum_error_l > MAX_ERROR):
        sum_error_l = MAX_ERROR
    elif (sum_error_l < -MAX_ERROR):
        sum_error_l = -MAX_ERROR
    
    if (sum_error_r > MAX_ERROR):
        sum_error_r = MAX_ERROR
    elif (sum_error_r < -MAX_ERROR):
        sum_error_r = -MAX_ERROR    
    
    l_speed = int(KP*error_l + KI*sum_error_l)
    r_speed = int(KP*error_r + KI*sum_error_r)
    
    print("left = ", l_speed)
    print("right = ", r_speed)
    
    if (l_speed > MAX_SPEED):
        l_speed = MAX_SPEED
    elif (l_speed < -MAX_SPEED):
        l_speed = -MAX_SPEED
    if (r_speed > MAX_SPEED):
        r_speed = MAX_SPEED
    elif (r_speed < -MAX_SPEED):
        r_speed = -MAX_SPEED
        
    if (test_ground_white()):
        if(turn_left):
            l_speed = SPEED - l_speed//4 
            r_speed = SPEED + r_speed//2
        elif(lost):
            l_speed = MAX_SPEED
            r_speed = -MAX_SPEED
        else:
            l_speed = SPEED + l_speed//2 
            r_speed = SPEED - r_speed//4
    else:
        l_speed = 2*SPEED + l_speed//2
        r_speed = 2*SPEED + r_speed//2
   
    l_speed = (2*l_speed + l_s_old)//3
    r_speed = (2*r_speed + r_s_old)//3
    
    l_s_old = l_speed
    r_s_old = r_speed
    
    return l_speed, r_speed

# %% [markdown]
# A demander pourquoi est ce que je suis obligée d'appeler la fonction test_white avant de l'utiliser dans go_straight alors que je n'ai pas ce problème avec la fonction motor!

# %%
async def go_straight(motor_speed=100, white_threshold=600, verbose=False):
    """
    Go Straight Behaviour of the FSM 
    param motor_speed: the Thymio's motor speed
    param white_threshold: threshold starting which it is considered that the ground sensor saw white
    param verbose: whether to print status messages or not
    """
    global prox_ground_reflected, test_ground_white, speed_l, speed_r
    if verbose: print("Starting go straight behaviour")
    
    l_speed, r_speed = await sync_to_async(PI)()
    
    # Move forward, i.e. set motor speeds
    motors(l_speed, r_speed)

    
    # Until one of the ground sensors sees some white
    saw_white = False
    
    
    while not saw_white:
        test_white = await sync_to_async(test_ground_white)(white_threshold, verbose=verbose)
        if test_white:
            saw_white=True
            if verbose: print("\t Saw white on the ground, exiting go straight behaviour")
        sleep(0.3) #otherwise, variables would not be updated
    return

# %%
if test_functions:
    await go_straight(100,500,True)
    motors(0, 0)
# Out:
# Starting go straight behaviour
# [89, 385]
# [90, 365]
# [90, 321]
# [97, 290]
# [104, 255]
# [116, 221]
# [131, 189]
# [147, 162]
# [187, 128]
# [257, 98]
# [327, 86]
# [426, 81]
# [593, 78]
# 593
# 	 Saw white on the ground, exiting go straight behaviour

# %% [markdown]
# In this function we will check is there's an obstacle on the lign the robot is following. If there's one, the robot will stop until the object is removed.

# %%
@tdmclient.notebook.sync_var
def test_object(prox_threshold=3000, verbose=False):
    """
    Tests whether the front proximity sensors saw an object on its way
    param prox_threshold: threshold starting which it is considered that the sensor saw an object
    param verbose: whether to print status messages or not
    """
    global prox_horizontal, leds_circle
    
    if (prox_horizontal[2]>prox_threshold):
        if verbose: print("\t\t Saw a wall")
        leds_circle = [LED,LED,LED,LED,LED,LED,LED,LED]
        return True
    else:
        leds_circle = [0,0,0,0,0,0,0,0]
        return False

# %% [markdown]
# Line following function

# %%
async def line_following(motor_speed=30, prox_threshold=3000, white_threshold=600, verbose=False):
    """
    Line following behaviour of the FSM
    param motor_speed: the Thymio's motor speed
    param wall_threshold: threshold starting which it is considered that the sensor saw a wall
    param white_threshold: threshold starting which it is considered that the ground sensor saw white
    param verbose: whether to print status messages or not
    """
    global motors, test_ground_white, test_object, lost, speed_l, speed_r
    
    if verbose: print("Starting line following behaviour")
    saw_wall = False
    
    if verbose: print("\t Moving forward")
   # motors(motor_speed, motor_speed)
       
    prev_state="forward"

    
    while not saw_wall:
        test_white = await sync_to_async(test_ground_white)(white_threshold)
        if test_white:
            if prev_state=="forward": 
                if (turn_left):
                    if verbose: print("\t Saw white to the right, turning left")
                    motors(SPEED, r_speed)
                    prev_state="turning"
                else:
                    if verbose: print("\t Saw white to the left, turning right")
                    if lost:
                        motors(l_speed, -motor_speed//2)
                    else:
                        
                        motors(motor_speed//2, motor_speed//2)
                    prev_state="turning"
                        
        else:
            if prev_state=="turning": 
                if verbose: print("\t Moving forward")
                motors(motor_speed, motor_speed)
                prev_state="forward"

        t_object = await sync_to_async(test_object)(prox_threshold,verbose)
        if t_object: 
            saw_wall = True
        sleep(0.3) #otherwise, variables would not be updated     
    return

# %%
if test_functions:
    await line_following(verbose=True, motor_speed=20)
    motors(0, 0)
# Out:
# Starting line following behaviour
# 	 Moving forward
# [145, 276]
# [145, 276]
# [144, 276]
# [168, 307]
# [129, 349]
# [171, 346]
# [170, 455]
# [155, 348]
# [127, 405]
# [131, 448]
# [113, 466]
# [111, 473]
# [111, 473]
# [111, 473]
# [113, 598]
# 598
# 	 Saw white to the right, turning left
# [80, 588]
# 588
# [85, 445]
# 	 Moving forward
# [85, 445]
# [93, 301]
# [121, 197]
# [195, 126]
# [194, 126]
# [192, 126]
# [185, 130]
# [180, 133]
# [180, 133]
# [180, 133]
# [165, 144]
# [156, 149]
# [151, 151]
# [145, 155]
# [145, 155]
# [137, 166]
# [135, 169]
# [132, 174]
# [132, 174]
# [123, 194]
# [123, 194]
# [116, 212]
# [113, 222]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /var/folders/w4/rlzv9syd0416nt9tchvspk1m0000gn/T/ipykernel_65738/121287060.py in <module>
#       1 if test_functions:
# ----> 2     await line_following(verbose=True, motor_speed=20)
#       3     motors(0, 0)
#
# /var/folders/w4/rlzv9syd0416nt9tchvspk1m0000gn/T/ipykernel_65738/1680114283.py in line_following(motor_speed, prox_threshold, white_threshold, verbose)
#      19
#      20     while not saw_wall:
# ---> 21         test_white = await sync_to_async(test_ground_white)(white_threshold)
#      22         if test_white:
#      23             if prev_state=="forward":
#
# ~/Library/Python/3.8/lib/python/site-packages/asgiref/sync.py in __call__(self, *args, **kwargs)
#     442                 ),
#     443             )
# --> 444             ret = await asyncio.wait_for(future, timeout=None)
#     445
#     446         finally:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py in wait_for(fut, timeout, loop)
#     453
#     454     if timeout is None:
# --> 455         return await fut
#     456
#     457     if timeout <= 0:
#
# CancelledError:

# %% [markdown]
# # FSM

# %%
async def g_path_FSM(speed, verbose=True):
      while True:
        # Step 1: line following
        #speed_l, speed_r = PI()
        #await line_following(speed, verbose=verbose)

        # Step 2: 
        await go_straight(speed, verbose=verbose)
        #print(speed_l,speed_r)

# %%
if test_functions:
    #constants
    LED = 32

    lost = False
    w_le_old = 0 
    w_ri_old = 0
    
    light_em_up()
    
    await g_path_FSM(10, verbose=True)
# Out:
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8350
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8390
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8350
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8330
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8390
# right =  8340
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8350
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8350
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8340
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8330
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8340
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8330
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8350
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8400
# right =  8340
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8410
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8340
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8330
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8350
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8340
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8330
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8410
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8340
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8390
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8400
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8350
# right =  8340
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8330
# right =  8330
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8320
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8350
# 	 Saw white on the ground, exiting go straight behaviour
# Starting go straight behaviour
# left =  8320
# right =  8360

# %%
motors(0,0)
