# %%
import tdmclient.notebook
await tdmclient.notebook.start()

# %%
import cv2
import math
import time

import numpy as np
import matplotlib.pyplot as plt
from numpy.core.fromnumeric import size
from matplotlib import colors
#from asgiref.sync import sync_to_async #in order to load variables to communicate between sync and async

# %%
import optimal_path as op

from robot import Robot
from Map import Map
from Local_navigation import* 
from Mouvement import*
from vision import*
from optimal_path import* 
from KalmanFilter import*


map_lenght = 1
nb_of_square_by_side = 50
current = 1

# %%
@tdmclient.notebook.sync_var
def motors(l_speed=500, r_speed=500, verbose=False):
    """
    Sets the motor speeds of the Thymio 
    param l_speed: left motor speed
    param r_speed: right motor speed
    param verbose: whether to print status messages or not
    """
    global motor_left_target, motor_right_target
    # Printing the speeds if requested
    if verbose:
        print("\t\t Setting speed : ", l_speed, r_speed)
    motor_left_target = l_speed
    motor_right_target = r_speed

# %%
def angle_of_vectors(a,b,c,d):
       
    vec_a = np.array([a, b])
    vec_b = np.array([c, d])

    inner = np.inner(vec_a, vec_b)
    norms = LA.norm(vec_a) * LA.norm(vec_b)

    cos = inner / norms
    rad = np.arccos(np.clip(cos, -1.0, 1.0))
    
    if b > 0:
        rad = rad * (-1)
    
    return rad

# %%
np.set_printoptions(threshold=sys.maxsize)
####################################
## INIT
####################################

VideoCap=cv2.VideoCapture(0)

KF=KalmanFilter(0.03, [0.0, 0])
x_old = 0
y_old = 0

# Prend une première image
ret, frame = VideoCap.read()
print("taille frame", frame.shape)


old_distance = 0
old_angle = 0
t = 10000
while t>0:
    start = time.time()
    
    print("The time used to execute this is given below")

   
    #ret, frame=VideoCap.read()
    #display(frame,1,0,0)
    ret, frame=VideoCap.read()
    #vs.display (frame, 0, 1, 1, 0, 5, Lausanne.get_pourcentage())
    pos_robot, angle_robot = update(frame, 0.104)  # fonction qui retourne la position angle etc....
    
    goal_nour = np.array([[2],[30]])
    
    #speed_l, speed_r, old_distance, old_angle = move_to_position(pos_robot, angle_robot, goal_nour, 0, 0)
    
   
    motors (100,100)
        
    
    
    #motors(speed_l, speed_r) 
    
    v_x = pos_robot[0] - x_old
    v_y = pos_robot[1] - y_old
    
    angle = angle_of_vectors(v_x,v_y,1,0)
    print('l angle est ', angle)
    print('l angle camera est ',angle_robot )
    
    speed = ( 100 + 100)/ 2
    speed = speed / 45.045
    print(' la vitesse moyen est', speed)

    speed_x = speed*np.cos(angle_robot)
    speed_y = speed*np.sin(angle_robot)
    
    if (len(pos_robot)>0):
        array = np.array([ 0,0,0,0.0])
        array[0] = float(pos_robot[0])
        array[1] = float(pos_robot[1])
        array[2] = float(speed_x)
        array[3] = float(speed_y)
        etat = KF.predict().astype(np.float64)
        KF.update(np.expand_dims(array, axis=-1))
        print(' les points avec vitesse sont',  pos_robot, speed_x, speed_y)
        print(' les points du kF sont', etat)
    display (frame, 1, 1, 1, 1, goal_nour, 0.04)
    
    x_old = pos_robot[0]
    y_old = pos_robot[1]
    
    end = time.time()

    print('le temps d execution est de',end - start)
    
   # 0.104
    
    if cv2.waitKey(1)&0xFF==ord('q'):
        print('le bouton quitter')
        motors(0, 0)         
        vision_end(VideoCap)
        break
# Out:
# taille frame (480, 640, 3)
# The time used to execute this is given below
# <ipython-input-5-16054178a2fe>:9: RuntimeWarning: invalid value encountered in true_divide
#   cos = inner / norms
# l angle est  nan
# l angle camera est  0
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (0, 0) 2.22000222000222 0.0
#  les points du kF sont [[0.]
#  [0.]
#  [0.]
#  [0.]]
# le temps d execution est de 0.3457317352294922
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  0
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.028922557830810547
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1223642544900856
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.21959183045809 -0.042684458278041175
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.027022361755371094
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1223642544900856
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.21959183045809 -0.042684458278041175
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.03234386444091797
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1223642544900856
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.21959183045809 -0.042684458278041175
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.0290071964263916
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1223642544900856
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.21959183045809 -0.042684458278041175
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.03372955322265625
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1223642544900856
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.21959183045809 -0.042684458278041175
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.026416301727294922
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1223642544900856
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.21959183045809 -0.042684458278041175
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.028413772583007812
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.1031500635686053
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.2183620260435437 -0.08532161638628995
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.05003190040588379
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.121987322732585
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.219575583653512 -0.04352108987556706
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.03702664375305176
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.121987322732585
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.219575583653512 -0.04352108987556706
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.02402186393737793
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.121987322732585
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.219575583653512 -0.04352108987556706
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.025969982147216797
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.121987322732585
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.219575583653512 -0.04352108987556706
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.036315202713012695
# The time used to execute this is given below
# l angle est  nan
# l angle camera est  -3.121987322732585
#  la vitesse moyen est 2.22000222000222
# la valeur  b est 1
#  les points avec vitesse sont (35, 8) -2.219575583653512 -0.04352108987556706
#  les points du kF sont [[34.94]
#  [ 8.  ]
#  [-2.  ]
#  [ 0.  ]]
# le temps d execution est de 0.025004863739013672
# The time used to execute this is given below
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-2f126a7ce8da> in <module>
#      35
#      36
# ---> 37     motors (100,100)
#      38
#      39
#
# ~\anaconda3\lib\site-packages\tdmclient\notebook\__init__.py in func_wrapper(*args, **kwargs)
#     158         node = get_node()
#     159         vars_to_sync = candidates & {_interactive_console.to_python_name(name) for name in node.var.keys()}
# --> 160         _interactive_console.fetch_variables(vars_to_sync)
#     161         r = func(*args, **kwargs)
#     162         _interactive_console.send_variables(vars_to_sync)
#
# ~\anaconda3\lib\site-packages\tdmclient\repl.py in fetch_variables(self, names_py, node_flush)
#     443
#     444         if node_flush:
# --> 445             self.node.flush()
#     446         for name_py in names_py:
#     447             self.local_var[name_py] = self.fetch_variable(name_py,
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasynccachenode.py in flush(self)
#     143         self.send_set_variables(self.var_to_send)
#     144         # process waiting messages, possibly changing self.var
# --> 145         self.thymio.process_waiting_messages()
#     146         # overwrite variables just sent in case they've been replaced by older values
#     147         self.var = {**self.var, **self.var_to_send}
#
# ~\anaconda3\lib\site-packages\tdmclient\client.py in process_waiting_messages(self)
#     128                 if self.debug >= 3:
#     129                     print("recv", msg)
# --> 130                 self.process_message(msg)
#     131                 at_least_one = True
#     132         return at_least_one
#
# ~\anaconda3\lib\site-packages\tdmclient\thymio.py in process_message(self, msg)
#     583
#     584         fb = FlatBuffer()
# --> 585         fb.parse(msg, ThymioFB.SCHEMA)
#     586         if self.debug >= 2:
#     587             fb.dump()
#
# ~\anaconda3\lib\site-packages\tdmclient\fb.py in parse(self, encoded_fb, schema)
#     164         if schema[0] not in "TU":
#     165             raise Exception("unexpected schema")
# --> 166         self.root = FlatBuffer.parse_value(encoded_fb, 0, schema)
#     167
#     168     @staticmethod
#
# ~\anaconda3\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     290             if len(vtable) > 1:
#     291                 pos_field = table_pos + vtable[1]
# --> 292                 union_value = FlatBuffer.parse_value(encoded_fb,
#     293                                                      pos_field,
#     294                                                      schema[ix_schema:])
#
# ~\anaconda3\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     254                     # decode field
#     255                     pos_field = table_pos + vtable[len(fields)]
# --> 256                     field_value = FlatBuffer.parse_value(encoded_fb,
#     257                                                          pos_field,
#     258                                                          schema[ix_schema:])
#
# ~\anaconda3\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     228                 for i in range(vec_len):
#     229                     # decode element
# --> 230                     els.append(FlatBuffer.parse_value(encoded_fb,
#     231                                                       vec_pos + 4 + i * el_size,
#     232                                                       schema[1:]))
#
# ~\anaconda3\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     254                     # decode field
#     255                     pos_field = table_pos + vtable[len(fields)]
# --> 256                     field_value = FlatBuffer.parse_value(encoded_fb,
#     257                                                          pos_field,
#     258                                                          schema[ix_schema:])
#
# ~\anaconda3\lib\site-packages\tdmclient\fb.py in parse_value(encoded_fb, pos, schema)
#     215             str_pos = pos + FlatBuffer.decode_i32(encoded_fb, pos)
#     216             str_len = FlatBuffer.decode_u32(encoded_fb, str_pos)
# --> 217             return str(encoded_fb[str_pos + 4 : str_pos + 4 + str_len], "utf-8")
#     218         elif schema[0] == "*":
#     219             # decode vector
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 1: invalid continuation byte

# %%
motors(0, 0)

# %%
vision_end(VideoCap)
